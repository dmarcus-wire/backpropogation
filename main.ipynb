# %% [markdown]
# Import the necessary packages

# %%
from sklearn.preprocessing import LabelBinarizer
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from sklearn import datasets
import numpy as np

# %% [markdown]
# Neural Network Definition

# %%
class NeuralNetwork:
	# requires a single argument followed by an optional one
	# layers: list of integer that represents actual architecture
	# alpha: learning rate, applied during weight update phase
	def __init__(self, layers, alpha=0.1):
		# initialize the list of weights matrices, then store the
		# network architecture and learning rate
		self.W = []
		self.layers = layers
		self.alpha = alpha

		# start looping from the index of the first layer but
		# stop before we reach the last two layers
		for i in np.arange(0, len(layers) - 2):
			# randomly initialize a weight matrix connecting the
			# number of nodes in each respective layer together,
			# adding an extra node for the bias
			w = np.random.randn(layers[i] + 1, layers[i + 1] + 1)
			self.W.append(w / np.sqrt(layers[i]))

		# the last two layers are a special case where the input
		# connections need a bias term but the output does not
		w = np.random.randn(layers[-2] + 1, layers[-1])
		self.W.append(w / np.sqrt(layers[-2]))

	def __repr__(self):
		# construct and return a string that represents the network
		# architecture
		return "NeuralNetwork: {}".format(
			"-".join(str(l) for l in self.layers))

	def sigmoid(self, x):
		# compute and return the sigmoid activation value for a
		# given input value
		return 1.0 / (1 + np.exp(-x))

	def sigmoid_deriv(self, x):
		# compute the derivative of the sigmoid function ASSUMING
		# that `x` has already been passed through the `sigmoid`
		# function
		return x * (1 - x)

	def fit(self, X, y, epochs=1000, displayUpdate=100):
		# insert a column of 1's as the last entry in the feature
		# matrix -- this little trick allows us to treat the bias
		# as a trainable parameter within the weight matrix
		X = np.c_[X, np.ones((X.shape[0]))]

		# loop over the desired number of epochs
		for epoch in np.arange(0, epochs):
			# loop over each individual data point and train
			# our network on it
			for (x, target) in zip(X, y):
				self.fit_partial(x, target)

			# check to see if we should display a training update
			if epoch == 0 or (epoch + 1) % displayUpdate == 0:
				loss = self.calculate_loss(X, y)
				print("[INFO] epoch={}, loss={:.7f}".format(
					epoch + 1, loss))

	def fit_partial(self, x, y):
		# construct our list of output activations for each layer
		# as our data point flows through the network; the first
		# activation is a special case -- it's just the input
		# feature vector itself
		A = [np.atleast_2d(x)]

		# FEEDFORWARD:
		# loop over the layers in the network
		for layer in np.arange(0, len(self.W)):
			# feedforward the activation at the current layer by
			# taking the dot product between the activation and
			# the weight matrix -- this is called the "net input"
			# to the current layer
			net = A[layer].dot(self.W[layer])

			# computing the "net output" is simply applying our
			# non-linear activation function to the net input
			out = self.sigmoid(net)

			# once we have the net output, add it to our list of
			# activations
			A.append(out)

		# BACKPROPAGATION
		# the first phase of backpropagation is to compute the
		# difference between our *prediction* (the final output
		# activation in the activations list) and the true target
		# value
		error = A[-1] - y

		# from here, we need to apply the chain rule and build our
		# list of deltas `D`; the first entry in the deltas is
		# simply the error of the output layer times the derivative
		# of our activation function for the output value
		D = [error * self.sigmoid_deriv(A[-1])]

		# once you understand the chain rule it becomes super easy
		# to implement with a `for` loop -- simply loop over the
		# layers in reverse order (ignoring the last two since we
		# already have taken them into account)
		for layer in np.arange(len(A) - 2, 0, -1):
			# the delta for the current layer is equal to the delta
			# of the *previous layer* dotted with the weight matrix
			# of the current layer, followed by multiplying the delta
			# by the derivative of the non-linear activation function
			# for the activations of the current layer
			delta = D[-1].dot(self.W[layer].T)
			delta = delta * self.sigmoid_deriv(A[layer])
			D.append(delta)

		# since we looped over our layers in reverse order we need to
		# reverse the deltas
		D = D[::-1]

		# WEIGHT UPDATE PHASE
		# loop over the layers
		for layer in np.arange(0, len(self.W)):
			# update our weights by taking the dot product of the layer
			# activations with their respective deltas, then multiplying
			# this value by some small learning rate and adding to our
			# weight matrix -- this is where the actual "learning" takes
			# place
			self.W[layer] += -self.alpha * A[layer].T.dot(D[layer])

	def predict(self, X, addBias=True):
		# initialize the output prediction as the input features -- this
		# value will be (forward) propagated through the network to
		# obtain the final prediction
		p = np.atleast_2d(X)

		# check to see if the bias column should be added
		if addBias:
			# insert a column of 1's as the last entry in the feature
			# matrix (bias)
			p = np.c_[p, np.ones((p.shape[0]))]

		# loop over our layers in the network
		for layer in np.arange(0, len(self.W)):
			# computing the output prediction is as simple as taking
			# the dot product between the current activation value `p`
			# and the weight matrix associated with the current layer,
			# then passing this value through a non-linear activation
			# function
			p = self.sigmoid(np.dot(p, self.W[layer]))

		# return the predicted value
		return p

	def calculate_loss(self, X, targets):
		# make predictions for the input data points then compute
		# the loss
		targets = np.atleast_2d(targets)
		predictions = self.predict(X, addBias=False)
		loss = 0.5 * np.sum((predictions - targets) ** 2)

		# return the loss
		return loss

# %%
# construct the XOR dataset
X = np.array([[0, 0], [0, 1], [1, 0], [1, 1]])
y = np.array([[0], [1], [1], [0]])

# %%
# define our 2-2-1 neural network and train it
nn = NeuralNetwork([2, 2, 1], alpha=0.5)
nn.fit(X, y, epochs=20000)
# Out:
# [INFO] epoch=1, loss=0.6834818
# [INFO] epoch=100, loss=0.5001374
# [INFO] epoch=200, loss=0.5001965
# [INFO] epoch=300, loss=0.5002298
# [INFO] epoch=400, loss=0.5001749
# [INFO] epoch=500, loss=0.4999443
# [INFO] epoch=600, loss=0.4993694
# [INFO] epoch=700, loss=0.4980113
# [INFO] epoch=800, loss=0.4942884
# [INFO] epoch=900, loss=0.4819703
# [INFO] epoch=1000, loss=0.4436890
# [INFO] epoch=1100, loss=0.3769545
# [INFO] epoch=1200, loss=0.3248629
# [INFO] epoch=1300, loss=0.2973446
# [INFO] epoch=1400, loss=0.2827450
# [INFO] epoch=1500, loss=0.2741325
# [INFO] epoch=1600, loss=0.2682791
# [INFO] epoch=1700, loss=0.2632034
# [INFO] epoch=1800, loss=0.2559235
# [INFO] epoch=1900, loss=0.2345514
# [INFO] epoch=2000, loss=0.1949102
# [INFO] epoch=2100, loss=0.1691406
# [INFO] epoch=2200, loss=0.1557329
# [INFO] epoch=2300, loss=0.1481631
# [INFO] epoch=2400, loss=0.1434303
# [INFO] epoch=2500, loss=0.1402285
# [INFO] epoch=2600, loss=0.1379321
# [INFO] epoch=2700, loss=0.1362112
# [INFO] epoch=2800, loss=0.1348770
# [INFO] epoch=2900, loss=0.1338142
# [INFO] epoch=3000, loss=0.1329489
# [INFO] epoch=3100, loss=0.1322316
# [INFO] epoch=3200, loss=0.1316277
# [INFO] epoch=3300, loss=0.1311127
# [INFO] epoch=3400, loss=0.1306686
# [INFO] epoch=3500, loss=0.1302817
# [INFO] epoch=3600, loss=0.1299420
# [INFO] epoch=3700, loss=0.1296412
# [INFO] epoch=3800, loss=0.1293732
# [INFO] epoch=3900, loss=0.1291330
# [INFO] epoch=4000, loss=0.1289163
# [INFO] epoch=4100, loss=0.1287201
# [INFO] epoch=4200, loss=0.1285414
# [INFO] epoch=4300, loss=0.1283782
# [INFO] epoch=4400, loss=0.1282284
# [INFO] epoch=4500, loss=0.1280905
# [INFO] epoch=4600, loss=0.1279631
# [INFO] epoch=4700, loss=0.1278450
# [INFO] epoch=4800, loss=0.1277353
# [INFO] epoch=4900, loss=0.1276332
# [INFO] epoch=5000, loss=0.1275377
# [INFO] epoch=5100, loss=0.1274484
# [INFO] epoch=5200, loss=0.1273646
# [INFO] epoch=5300, loss=0.1272858
# [INFO] epoch=5400, loss=0.1272116
# [INFO] epoch=5500, loss=0.1271415
# [INFO] epoch=5600, loss=0.1270753
# [INFO] epoch=5700, loss=0.1270126
# [INFO] epoch=5800, loss=0.1269531
# [INFO] epoch=5900, loss=0.1268966
# [INFO] epoch=6000, loss=0.1268429
# [INFO] epoch=6100, loss=0.1267917
# [INFO] epoch=6200, loss=0.1267429
# [INFO] epoch=6300, loss=0.1266962
# [INFO] epoch=6400, loss=0.1266516
# [INFO] epoch=6500, loss=0.1266088
# [INFO] epoch=6600, loss=0.1265679
# [INFO] epoch=6700, loss=0.1265285
# [INFO] epoch=6800, loss=0.1264907
# [INFO] epoch=6900, loss=0.1264543
# [INFO] epoch=7000, loss=0.1264193
# [INFO] epoch=7100, loss=0.1263855
# [INFO] epoch=7200, loss=0.1263529
# [INFO] epoch=7300, loss=0.1263214
# [INFO] epoch=7400, loss=0.1262910
# [INFO] epoch=7500, loss=0.1262615
# [INFO] epoch=7600, loss=0.1262329
# [INFO] epoch=7700, loss=0.1262051
# [INFO] epoch=7800, loss=0.1261782
# [INFO] epoch=7900, loss=0.1261520
# [INFO] epoch=8000, loss=0.1261264
# [INFO] epoch=8100, loss=0.1261016
# [INFO] epoch=8200, loss=0.1260773
# [INFO] epoch=8300, loss=0.1260536
# [INFO] epoch=8400, loss=0.1260305
# [INFO] epoch=8500, loss=0.1260078
# [INFO] epoch=8600, loss=0.1259856
# [INFO] epoch=8700, loss=0.1259637
# [INFO] epoch=8800, loss=0.1259423
# [INFO] epoch=8900, loss=0.1259212
# [INFO] epoch=9000, loss=0.1259004
# [INFO] epoch=9100, loss=0.1258798
# [INFO] epoch=9200, loss=0.1258595
# [INFO] epoch=9300, loss=0.1258394
# [INFO] epoch=9400, loss=0.1258195
# [INFO] epoch=9500, loss=0.1257997
# [INFO] epoch=9600, loss=0.1257799
# [INFO] epoch=9700, loss=0.1257602
# [INFO] epoch=9800, loss=0.1257405
# [INFO] epoch=9900, loss=0.1257207
# [INFO] epoch=10000, loss=0.1257008
# [INFO] epoch=10100, loss=0.1256808
# [INFO] epoch=10200, loss=0.1256606
# [INFO] epoch=10300, loss=0.1256400
# [INFO] epoch=10400, loss=0.1256192
# [INFO] epoch=10500, loss=0.1255978
# [INFO] epoch=10600, loss=0.1255760
# [INFO] epoch=10700, loss=0.1255535
# [INFO] epoch=10800, loss=0.1255302
# [INFO] epoch=10900, loss=0.1255060
# [INFO] epoch=11000, loss=0.1254808
# [INFO] epoch=11100, loss=0.1254543
# [INFO] epoch=11200, loss=0.1254263
# [INFO] epoch=11300, loss=0.1253965
# [INFO] epoch=11400, loss=0.1253646
# [INFO] epoch=11500, loss=0.1253301
# [INFO] epoch=11600, loss=0.1252926
# [INFO] epoch=11700, loss=0.1252514
# [INFO] epoch=11800, loss=0.1252056
# [INFO] epoch=11900, loss=0.1251542
# [INFO] epoch=12000, loss=0.1250956
# [INFO] epoch=12100, loss=0.1250280
# [INFO] epoch=12200, loss=0.1249487
# [INFO] epoch=12300, loss=0.1248538
# [INFO] epoch=12400, loss=0.1247376
# [INFO] epoch=12500, loss=0.1245917
# [INFO] epoch=12600, loss=0.1244023
# [INFO] epoch=12700, loss=0.1241463
# [INFO] epoch=12800, loss=0.1237821
# [INFO] epoch=12900, loss=0.1232260
# [INFO] epoch=13000, loss=0.1222888
# [INFO] epoch=13100, loss=0.1204540
# [INFO] epoch=13200, loss=0.1158556
# [INFO] epoch=13300, loss=0.0972569
# [INFO] epoch=13400, loss=0.0314557
# [INFO] epoch=13500, loss=0.0148650
# [INFO] epoch=13600, loss=0.0097223
# [INFO] epoch=13700, loss=0.0071741
# [INFO] epoch=13800, loss=0.0056728
# [INFO] epoch=13900, loss=0.0046890
# [INFO] epoch=14000, loss=0.0039965
# [INFO] epoch=14100, loss=0.0034832
# [INFO] epoch=14200, loss=0.0030878
# [INFO] epoch=14300, loss=0.0027740
# [INFO] epoch=14400, loss=0.0025188
# [INFO] epoch=14500, loss=0.0023073
# [INFO] epoch=14600, loss=0.0021291
# [INFO] epoch=14700, loss=0.0019769
# [INFO] epoch=14800, loss=0.0018453
# [INFO] epoch=14900, loss=0.0017305
# [INFO] epoch=15000, loss=0.0016294
# [INFO] epoch=15100, loss=0.0015397
# [INFO] epoch=15200, loss=0.0014595
# [INFO] epoch=15300, loss=0.0013874
# [INFO] epoch=15400, loss=0.0013222
# [INFO] epoch=15500, loss=0.0012630
# [INFO] epoch=15600, loss=0.0012090
# [INFO] epoch=15700, loss=0.0011595
# [INFO] epoch=15800, loss=0.0011140
# [INFO] epoch=15900, loss=0.0010719
# [INFO] epoch=16000, loss=0.0010330
# [INFO] epoch=16100, loss=0.0009969
# [INFO] epoch=16200, loss=0.0009632
# [INFO] epoch=16300, loss=0.0009318
# [INFO] epoch=16400, loss=0.0009024
# [INFO] epoch=16500, loss=0.0008749
# [INFO] epoch=16600, loss=0.0008490
# [INFO] epoch=16700, loss=0.0008246
# [INFO] epoch=16800, loss=0.0008016
# [INFO] epoch=16900, loss=0.0007799
# [INFO] epoch=17000, loss=0.0007593
# [INFO] epoch=17100, loss=0.0007399
# [INFO] epoch=17200, loss=0.0007214
# [INFO] epoch=17300, loss=0.0007038
# [INFO] epoch=17400, loss=0.0006871
# [INFO] epoch=17500, loss=0.0006711
# [INFO] epoch=17600, loss=0.0006559
# [INFO] epoch=17700, loss=0.0006414
# [INFO] epoch=17800, loss=0.0006275
# [INFO] epoch=17900, loss=0.0006143
# [INFO] epoch=18000, loss=0.0006015
# [INFO] epoch=18100, loss=0.0005893
# [INFO] epoch=18200, loss=0.0005776
# [INFO] epoch=18300, loss=0.0005664
# [INFO] epoch=18400, loss=0.0005556
# [INFO] epoch=18500, loss=0.0005452
# [INFO] epoch=18600, loss=0.0005352
# [INFO] epoch=18700, loss=0.0005255
# [INFO] epoch=18800, loss=0.0005162
# [INFO] epoch=18900, loss=0.0005073
# [INFO] epoch=19000, loss=0.0004986
# [INFO] epoch=19100, loss=0.0004902
# [INFO] epoch=19200, loss=0.0004822
# [INFO] epoch=19300, loss=0.0004743
# [INFO] epoch=19400, loss=0.0004668
# [INFO] epoch=19500, loss=0.0004595
# [INFO] epoch=19600, loss=0.0004524
# [INFO] epoch=19700, loss=0.0004455
# [INFO] epoch=19800, loss=0.0004388
# [INFO] epoch=19900, loss=0.0004323
# [INFO] epoch=20000, loss=0.0004261

# %%
# now that our network is trained, loop over the XOR data points
for (x, target) in zip(X, y):
	# make a prediction on the data point and display the result
	# to our console
	pred = nn.predict(x)[0][0]
	step = 1 if pred > 0.5 else 0
	print("[INFO] data={}, ground-truth={}, pred={:.4f}, step={}".format(
		x, target[0], pred, step))
# Out:
# [INFO] data=[0 0], ground-truth=0, pred=0.0163, step=0
# [INFO] data=[0 1], ground-truth=1, pred=0.9869, step=1
# [INFO] data=[1 0], ground-truth=1, pred=0.9843, step=1
# [INFO] data=[1 1], ground-truth=0, pred=0.0128, step=0

# %%
# define our 2-1 neural network and train it
nn = NeuralNetwork([2, 1], alpha=0.5)
nn.fit(X, y, epochs=20000)
# Out:
# [INFO] epoch=1, loss=0.6763632
# [INFO] epoch=100, loss=0.5018390
# [INFO] epoch=200, loss=0.5009159
# [INFO] epoch=300, loss=0.5008116
# [INFO] epoch=400, loss=0.5007965
# [INFO] epoch=500, loss=0.5007942
# [INFO] epoch=600, loss=0.5007939
# [INFO] epoch=700, loss=0.5007938
# [INFO] epoch=800, loss=0.5007938
# [INFO] epoch=900, loss=0.5007938
# [INFO] epoch=1000, loss=0.5007938
# [INFO] epoch=1100, loss=0.5007938
# [INFO] epoch=1200, loss=0.5007938
# [INFO] epoch=1300, loss=0.5007938
# [INFO] epoch=1400, loss=0.5007938
# [INFO] epoch=1500, loss=0.5007938
# [INFO] epoch=1600, loss=0.5007938
# [INFO] epoch=1700, loss=0.5007938
# [INFO] epoch=1800, loss=0.5007938
# [INFO] epoch=1900, loss=0.5007938
# [INFO] epoch=2000, loss=0.5007938
# [INFO] epoch=2100, loss=0.5007938
# [INFO] epoch=2200, loss=0.5007938
# [INFO] epoch=2300, loss=0.5007938
# [INFO] epoch=2400, loss=0.5007938
# [INFO] epoch=2500, loss=0.5007938
# [INFO] epoch=2600, loss=0.5007938
# [INFO] epoch=2700, loss=0.5007938
# [INFO] epoch=2800, loss=0.5007938
# [INFO] epoch=2900, loss=0.5007938
# [INFO] epoch=3000, loss=0.5007938
# [INFO] epoch=3100, loss=0.5007938
# [INFO] epoch=3200, loss=0.5007938
# [INFO] epoch=3300, loss=0.5007938
# [INFO] epoch=3400, loss=0.5007938
# [INFO] epoch=3500, loss=0.5007938
# [INFO] epoch=3600, loss=0.5007938
# [INFO] epoch=3700, loss=0.5007938
# [INFO] epoch=3800, loss=0.5007938
# [INFO] epoch=3900, loss=0.5007938
# [INFO] epoch=4000, loss=0.5007938
# [INFO] epoch=4100, loss=0.5007938
# [INFO] epoch=4200, loss=0.5007938
# [INFO] epoch=4300, loss=0.5007938
# [INFO] epoch=4400, loss=0.5007938
# [INFO] epoch=4500, loss=0.5007938
# [INFO] epoch=4600, loss=0.5007938
# [INFO] epoch=4700, loss=0.5007938
# [INFO] epoch=4800, loss=0.5007938
# [INFO] epoch=4900, loss=0.5007938
# [INFO] epoch=5000, loss=0.5007938
# [INFO] epoch=5100, loss=0.5007938
# [INFO] epoch=5200, loss=0.5007938
# [INFO] epoch=5300, loss=0.5007938
# [INFO] epoch=5400, loss=0.5007938
# [INFO] epoch=5500, loss=0.5007938
# [INFO] epoch=5600, loss=0.5007938
# [INFO] epoch=5700, loss=0.5007938
# [INFO] epoch=5800, loss=0.5007938
# [INFO] epoch=5900, loss=0.5007938
# [INFO] epoch=6000, loss=0.5007938
# [INFO] epoch=6100, loss=0.5007938
# [INFO] epoch=6200, loss=0.5007938
# [INFO] epoch=6300, loss=0.5007938
# [INFO] epoch=6400, loss=0.5007938
# [INFO] epoch=6500, loss=0.5007938
# [INFO] epoch=6600, loss=0.5007938
# [INFO] epoch=6700, loss=0.5007938
# [INFO] epoch=6800, loss=0.5007938
# [INFO] epoch=6900, loss=0.5007938
# [INFO] epoch=7000, loss=0.5007938
# [INFO] epoch=7100, loss=0.5007938
# [INFO] epoch=7200, loss=0.5007938
# [INFO] epoch=7300, loss=0.5007938
# [INFO] epoch=7400, loss=0.5007938
# [INFO] epoch=7500, loss=0.5007938
# [INFO] epoch=7600, loss=0.5007938
# [INFO] epoch=7700, loss=0.5007938
# [INFO] epoch=7800, loss=0.5007938
# [INFO] epoch=7900, loss=0.5007938
# [INFO] epoch=8000, loss=0.5007938
# [INFO] epoch=8100, loss=0.5007938
# [INFO] epoch=8200, loss=0.5007938
# [INFO] epoch=8300, loss=0.5007938
# [INFO] epoch=8400, loss=0.5007938
# [INFO] epoch=8500, loss=0.5007938
# [INFO] epoch=8600, loss=0.5007938
# [INFO] epoch=8700, loss=0.5007938
# [INFO] epoch=8800, loss=0.5007938
# [INFO] epoch=8900, loss=0.5007938
# [INFO] epoch=9000, loss=0.5007938
# [INFO] epoch=9100, loss=0.5007938
# [INFO] epoch=9200, loss=0.5007938
# [INFO] epoch=9300, loss=0.5007938
# [INFO] epoch=9400, loss=0.5007938
# [INFO] epoch=9500, loss=0.5007938
# [INFO] epoch=9600, loss=0.5007938
# [INFO] epoch=9700, loss=0.5007938
# [INFO] epoch=9800, loss=0.5007938
# [INFO] epoch=9900, loss=0.5007938
# [INFO] epoch=10000, loss=0.5007938
# [INFO] epoch=10100, loss=0.5007938
# [INFO] epoch=10200, loss=0.5007938
# [INFO] epoch=10300, loss=0.5007938
# [INFO] epoch=10400, loss=0.5007938
# [INFO] epoch=10500, loss=0.5007938
# [INFO] epoch=10600, loss=0.5007938
# [INFO] epoch=10700, loss=0.5007938
# [INFO] epoch=10800, loss=0.5007938
# [INFO] epoch=10900, loss=0.5007938
# [INFO] epoch=11000, loss=0.5007938
# [INFO] epoch=11100, loss=0.5007938
# [INFO] epoch=11200, loss=0.5007938
# [INFO] epoch=11300, loss=0.5007938
# [INFO] epoch=11400, loss=0.5007938
# [INFO] epoch=11500, loss=0.5007938
# [INFO] epoch=11600, loss=0.5007938
# [INFO] epoch=11700, loss=0.5007938
# [INFO] epoch=11800, loss=0.5007938
# [INFO] epoch=11900, loss=0.5007938
# [INFO] epoch=12000, loss=0.5007938
# [INFO] epoch=12100, loss=0.5007938
# [INFO] epoch=12200, loss=0.5007938
# [INFO] epoch=12300, loss=0.5007938
# [INFO] epoch=12400, loss=0.5007938
# [INFO] epoch=12500, loss=0.5007938
# [INFO] epoch=12600, loss=0.5007938
# [INFO] epoch=12700, loss=0.5007938
# [INFO] epoch=12800, loss=0.5007938
# [INFO] epoch=12900, loss=0.5007938
# [INFO] epoch=13000, loss=0.5007938
# [INFO] epoch=13100, loss=0.5007938
# [INFO] epoch=13200, loss=0.5007938
# [INFO] epoch=13300, loss=0.5007938
# [INFO] epoch=13400, loss=0.5007938
# [INFO] epoch=13500, loss=0.5007938
# [INFO] epoch=13600, loss=0.5007938
# [INFO] epoch=13700, loss=0.5007938
# [INFO] epoch=13800, loss=0.5007938
# [INFO] epoch=13900, loss=0.5007938
# [INFO] epoch=14000, loss=0.5007938
# [INFO] epoch=14100, loss=0.5007938
# [INFO] epoch=14200, loss=0.5007938
# [INFO] epoch=14300, loss=0.5007938
# [INFO] epoch=14400, loss=0.5007938
# [INFO] epoch=14500, loss=0.5007938
# [INFO] epoch=14600, loss=0.5007938
# [INFO] epoch=14700, loss=0.5007938
# [INFO] epoch=14800, loss=0.5007938
# [INFO] epoch=14900, loss=0.5007938
# [INFO] epoch=15000, loss=0.5007938
# [INFO] epoch=15100, loss=0.5007938
# [INFO] epoch=15200, loss=0.5007938
# [INFO] epoch=15300, loss=0.5007938
# [INFO] epoch=15400, loss=0.5007938
# [INFO] epoch=15500, loss=0.5007938
# [INFO] epoch=15600, loss=0.5007938
# [INFO] epoch=15700, loss=0.5007938
# [INFO] epoch=15800, loss=0.5007938
# [INFO] epoch=15900, loss=0.5007938
# [INFO] epoch=16000, loss=0.5007938
# [INFO] epoch=16100, loss=0.5007938
# [INFO] epoch=16200, loss=0.5007938
# [INFO] epoch=16300, loss=0.5007938
# [INFO] epoch=16400, loss=0.5007938
# [INFO] epoch=16500, loss=0.5007938
# [INFO] epoch=16600, loss=0.5007938
# [INFO] epoch=16700, loss=0.5007938
# [INFO] epoch=16800, loss=0.5007938
# [INFO] epoch=16900, loss=0.5007938
# [INFO] epoch=17000, loss=0.5007938
# [INFO] epoch=17100, loss=0.5007938
# [INFO] epoch=17200, loss=0.5007938
# [INFO] epoch=17300, loss=0.5007938
# [INFO] epoch=17400, loss=0.5007938
# [INFO] epoch=17500, loss=0.5007938
# [INFO] epoch=17600, loss=0.5007938
# [INFO] epoch=17700, loss=0.5007938
# [INFO] epoch=17800, loss=0.5007938
# [INFO] epoch=17900, loss=0.5007938
# [INFO] epoch=18000, loss=0.5007938
# [INFO] epoch=18100, loss=0.5007938
# [INFO] epoch=18200, loss=0.5007938
# [INFO] epoch=18300, loss=0.5007938
# [INFO] epoch=18400, loss=0.5007938
# [INFO] epoch=18500, loss=0.5007938
# [INFO] epoch=18600, loss=0.5007938
# [INFO] epoch=18700, loss=0.5007938
# [INFO] epoch=18800, loss=0.5007938
# [INFO] epoch=18900, loss=0.5007938
# [INFO] epoch=19000, loss=0.5007938
# [INFO] epoch=19100, loss=0.5007938
# [INFO] epoch=19200, loss=0.5007938
# [INFO] epoch=19300, loss=0.5007938
# [INFO] epoch=19400, loss=0.5007938
# [INFO] epoch=19500, loss=0.5007938
# [INFO] epoch=19600, loss=0.5007938
# [INFO] epoch=19700, loss=0.5007938
# [INFO] epoch=19800, loss=0.5007938
# [INFO] epoch=19900, loss=0.5007938
# [INFO] epoch=20000, loss=0.5007938

# %%
# now that our network is trained, loop over the XOR data points
for (x, target) in zip(X, y):
	# make a prediction on the data point and display the result
	# to our console
	pred = nn.predict(x)[0][0]
	step = 1 if pred > 0.5 else 0
	print("[INFO] data={}, ground-truth={}, pred={:.4f}, step={}".format(
		x, target[0], pred, step))
# Out:
# [INFO] data=[0 0], ground-truth=0, pred=0.5161, step=1
# [INFO] data=[0 1], ground-truth=1, pred=0.5000, step=1
# [INFO] data=[1 0], ground-truth=1, pred=0.4839, step=0
# [INFO] data=[1 1], ground-truth=0, pred=0.4678, step=0

# %% [markdown]
# Backpropogation with Python Example

# %%
# load the MNIST dataset and apply min/max scaling to scale the
# pixel intensity values to the range [0, 1] (each image is
# represented by an 8 x 8 = 64-dim feature vector)
print("[INFO] loading MNIST (sample) dataset...")
digits = datasets.load_digits()
data = digits.data.astype("float")
data = (data - data.min()) / (data.max() - data.min())
print("[INFO] samples: {}, dim: {}".format(data.shape[0],
	data.shape[1]))
# Out:
# [INFO] loading MNIST (sample) dataset...
# [INFO] samples: 1797, dim: 64

# %%
# construct the training and testing splits
(trainX, testX, trainY, testY) = train_test_split(data,
	digits.target, test_size=0.25)

# convert the labels from integers to vectors
trainY = LabelBinarizer().fit_transform(trainY)
testY = LabelBinarizer().fit_transform(testY)

# %%
# train the network
print("[INFO] training network...")
nn = NeuralNetwork([trainX.shape[1], 32, 16, 10])
print("[INFO] {}".format(nn))
nn.fit(trainX, trainY, epochs=1000)
# Out:
# [INFO] training network...
# [INFO] NeuralNetwork: 64-32-16-10
# [INFO] epoch=1, loss=605.7496403
# [INFO] epoch=100, loss=5.7721209
# [INFO] epoch=200, loss=1.5675596
# [INFO] epoch=300, loss=1.0030482
# [INFO] epoch=400, loss=0.8295836
# [INFO] epoch=500, loss=0.7429804
# [INFO] epoch=600, loss=0.6913331
# [INFO] epoch=700, loss=0.6571863
# [INFO] epoch=800, loss=0.6330153
# [INFO] epoch=900, loss=0.6150514
# [INFO] epoch=1000, loss=0.6012029

# %%
# evaluate the network
print("[INFO] evaluating network...")
predictions = nn.predict(testX)
predictions = predictions.argmax(axis=1)
print(classification_report(testY.argmax(axis=1), predictions))
# Out:
# [INFO] evaluating network...
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        51
#            1       0.96      0.93      0.95        46
#            2       0.96      1.00      0.98        44
#            3       1.00      0.95      0.98        44
#            4       0.98      0.98      0.98        54
#            5       0.94      0.94      0.94        36
#            6       1.00      0.97      0.99        34
#            7       1.00      0.98      0.99        51
#            8       0.93      0.93      0.93        44
#            9       0.92      0.98      0.95        46
#
#     accuracy                           0.97       450
#    macro avg       0.97      0.97      0.97       450
# weighted avg       0.97      0.97      0.97       450
